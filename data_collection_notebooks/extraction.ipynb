# %% [markdown]
# ## Imports
#  First, I have imported the necessary libraries to be used in this project.

# %%
import ee
import geemap
import geopandas as gpd
import pandas as pd
import numpy as np
import seaborn as sns
import folium
import matplotlib.pyplot as plt

# %% [markdown]
# Proceed to autheniticate with Google Earth Engine. You will need a Google cloud project for this.

# %%
#Authenticate to the Earth Engine servers
ee.Authenticate()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# True

# %% [markdown]
# Then proceed to initialize to begin working with geemap.

# %%
#Initialize ee
ee.Initialize()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# *** Earth Engine *** Share your feedback by taking our Annual Developer Satisfaction Survey: https://google.qualtrics.com/jfe/form/SV_0JLhFqfSY1uiEaW?source=Init

# %% [markdown]
# ### Area of Interest
# - The area of interest for this project is Lake Victoria, shared by Kenya, Uganda and Tanzania.
# - Sanity checking the crs to ensure it corresponds to the satellite images to be used in the analysis.

# %%
#Load the lake geojson
lake = gpd.read_file('Lake_Victoria_Shapefile.geojson')
lake.crs
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
lake.plot()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <Axes: >

# %% [markdown]
# Here, I load Kenya's geojson file to perform a geometry operation that yields the interesction of the Lake and the country.

# %%
#Load Kenya geojson
kenya = gpd.read_file('kenya.geojson')
kenya.crs
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
kenya.head()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                      id abbreviati country_co country_na wld_rgn  \
# 0  000000000000000000c6                    KE      Kenya  Africa
#
#                                             geometry
# 0  MULTIPOLYGON (((40.9479 -2.22394, 40.94743 -2....

# %%
kenya.plot()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <Axes: >

# %% [markdown]
# Get the intersection.

# %%
# #Our study area is the intersection of the two
study_area = gpd.overlay(kenya, lake, how='intersection')
study_area.plot()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <Axes: >

# %%
study_area.explore()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_99f58bcc8930af08aa37ee4b700d28f8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_99f58bcc8930af08aa37ee4b700d28f8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_99f58bcc8930af08aa37ee4b700d28f8 = L.map(
#                 &quot;map_99f58bcc8930af08aa37ee4b700d28f8&quot;,
#                 {
#                     center: [-0.4064027191795025, 34.3883881862823],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_99f58bcc8930af08aa37ee4b700d28f8);
#
#
#
#
#
#             var tile_layer_835ad577f28957c3b17e93f40867f29e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_835ad577f28957c3b17e93f40867f29e.addTo(map_99f58bcc8930af08aa37ee4b700d28f8);
#
#
#             map_99f58bcc8930af08aa37ee4b700d28f8.fitBounds(
#                 [[-1.0464649601920237, 33.9103256347169], [0.23365952183301877, 34.8664507378477]],
#                 {}
#             );
#
#
#         function geo_json_4ba167919446130a978319b900dff3c8_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_4ba167919446130a978319b900dff3c8_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_4ba167919446130a978319b900dff3c8_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_4ba167919446130a978319b900dff3c8_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_4ba167919446130a978319b900dff3c8_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_4ba167919446130a978319b900dff3c8.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_4ba167919446130a978319b900dff3c8_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_4ba167919446130a978319b900dff3c8 = L.geoJson(null, {
#                 onEachFeature: geo_json_4ba167919446130a978319b900dff3c8_onEachFeature,
#
#                 style: geo_json_4ba167919446130a978319b900dff3c8_styler,
#                 pointToLayer: geo_json_4ba167919446130a978319b900dff3c8_pointToLayer,
#         });
#
#         function geo_json_4ba167919446130a978319b900dff3c8_add (data) {
#             geo_json_4ba167919446130a978319b900dff3c8
#                 .addData(data);
#         }
#             geo_json_4ba167919446130a978319b900dff3c8_add({&quot;bbox&quot;: [33.9103256347169, -1.0464649601920237, 34.8664507378477, 0.23365952183301877], &quot;features&quot;: [{&quot;bbox&quot;: [33.9103256347169, -1.0464649601920237, 34.8664507378477, 0.23365952183301877], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[33.922203213602366, 0.11769704290082729], [33.93989301790539, 0.14192661929758127], [33.95758273206546, 0.16615615619893248], [33.975272520563095, 0.190385731238364], [33.98363537998309, 0.20184026993407955], [34.001325149973916, 0.22606984173007155], [34.006844131422795, 0.23362917924953622], [34.00686229379463, 0.23365952183301877], [34.0081974283857, 0.232766503228501], [34.00916531033, 0.232786254883199], [34.0100775824657, 0.231555548774294], [34.012224934896, 0.230002780490

# %%
# Here I export the study area to a shapefile and zipped it, uploaded it 
# as an asset to my GEE account for optimal performance
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# #Export it as shapefile
study_area.to_file('study_area.shp')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### How to load the asset.
# - After uploading the asset, a link for it will be created, which you can use to load it as in the cell below.

# %%
#Load the study area asset uploaded to ee
lake_asset = 'projects/water-quality-441207/assets/lake_victoria_ke'
lake = ee.FeatureCollection(lake_asset)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# After getting the region of interest in order, we can proceed to get the relevant satellite images. We can create an interactive map for visualizing the data and inspection but I won't do that in this notebook (check images.ipynb), we are interested in the data collection part and collection.

# %% [markdown]
# ### Dataset
# - The dataset used in the zonal statistics calculations: https://developers.google.com/earth-engine/datasets/catalog/MODIS_061_MYD09GA
# - I have selected the relevant bands.

# %%
#Load the MODIS image collection
dataset = ee.ImageCollection('MODIS/061/MYD09GA') \
            .filterDate('2002-07-04', '2024-11-12') \
            .select(['sur_refl_b01', 'sur_refl_b02', 'sur_refl_b03', 
                     'sur_refl_b04', 'sur_refl_b05', 'sur_refl_b06', 'sur_refl_b07'])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Spectral Indices
# - The spectral indices used are NDCI, Chlorophyll-a, Suspended Solids Concentration and Turbidity.

# %%
# Calculate indices for water quality
def calculate_indices(image):
    ndci = image.normalizedDifference(['sur_refl_b05', 'sur_refl_b04']).rename('NDCI')  # NIR and Red
    chl_a = image.expression(
        'exp(0.15 * (B3 / B4))',  # Empirical formula with Blue (B3) and Green (B4)
        {'B3': image.select('sur_refl_b03'), 'B4': image.select('sur_refl_b04')}
    ).rename('Chlorophyll_a')
    ssc = image.expression(
        '0.1 * pow(B3, 1.5)',  # Example SSC formula using Red (B3)
        {'B3': image.select('sur_refl_b03')}
    ).rename('SSC')
    turbidity = image.expression(
        '0.02 * pow(B3, 1.3)',  # Example Turbidity formula using Red (B3)
        {'B3': image.select('sur_refl_b03')}
    ).rename('Turbidity')
    return image.addBands([ndci, chl_a, ssc, turbidity])

# Apply index calculations to the dataset
processed_dataset = dataset.map(calculate_indices)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# The data collected spans from the date when data was first made available up to date

# %%
# Define the date range
start_date = '2002-07-04'
end_date = '2024-11-12'
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Define the function to compute monthly NDCI averages
def compute_monthly_ndci_averages(start_date, end_date, lake, scale=1000):
    # Define the date range
    start = ee.Date(start_date)
    end = ee.Date(end_date)
    
    # Generate a list of months
    months = pd.date_range(start_date, end_date, freq='MS').strftime("%Y-%m").tolist()

    all_stats = []

    for month in months:
        month_start = ee.Date(f'{month}-01')
        month_end = month_start.advance(1, 'month')
        
        # Filter the dataset for the month and select the NDCI band
        monthly_ndci = processed_dataset.filterDate(month_start, month_end).select('NDCI').mean()
        
        # Ensure the image has the band
        if monthly_ndci.bandNames().size().getInfo() == 0:
            print(f"No data for {month}")
            continue
        
        # Compute the zonal statistics for the region
        stats = geemap.zonal_stats(
            monthly_ndci, 
            lake, 
            None,  # No need to save intermediate files
            stat_type='MEAN', 
            scale=scale, 
            return_fc=True
        )
        
        # Convert the results to a DataFrame and add the month column
        df = geemap.ee_to_df(stats)
        df['month'] = month
        all_stats.append(df)
    
    # Concatenate all monthly DataFrames into a single DataFrame
    final_df = pd.concat(all_stats, ignore_index=True)
    
    # Save the final DataFrame to a CSV file
    final_output_file = 'monthly_ndci_averages.csv'
    final_df.to_csv(final_output_file, index=False)
    
    return final_output_file

# %%
# Compute the monthly NDCI averages
final_output_file = compute_monthly_ndci_averages(start_date, end_date, lake)
print(f'Monthly NDCI averages saved to {final_output_file}')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Monthly NDCI averages saved to monthly_ndci_averages.csv

# %%
# Define the function to compute monthly Chlorophyll_a averages
def compute_monthly_chlorophyll_a_averages(start_date, end_date, lake, scale=500):
    # Define the date range
    start = ee.Date(start_date)
    end = ee.Date(end_date)
    
    # Generate a list of months
    months = pd.date_range(start_date, end_date, freq='MS').strftime("%Y-%m").tolist()

    all_stats = []

    for month in months:
        month_start = ee.Date(f'{month}-01')
        month_end = month_start.advance(1, 'month')
        
        # Filter the dataset for the month and select the NDCI band
        monthly_ndci = processed_dataset.filterDate(month_start, month_end).select('Chlorophyll_a').mean()
        
        # Ensure the image has the band
        if monthly_ndci.bandNames().size().getInfo() == 0:
            print(f"No data for {month}")
            continue
        
        # Compute the zonal statistics for the region
        stats = geemap.zonal_stats(
            monthly_ndci, 
            lake, 
            None,  # No need to save intermediate files
            stat_type='MEAN', 
            scale=scale, 
            return_fc=True
        )
        
        # Convert the results to a DataFrame and add the month column
        df = geemap.ee_to_df(stats)
        df['month'] = month
        all_stats.append(df)
    
    # Concatenate all monthly DataFrames into a single DataFrame
    final_df = pd.concat(all_stats, ignore_index=True)
    
    # Save the final DataFrame to a CSV file
    final_output_file = 'monthly_Chlorophyll_a_averages.csv'
    final_df.to_csv(final_output_file, index=False)
    
    return final_output_file

# %%
# Compute the monthly chlorophyll-a averages
final_output_file = compute_monthly_chlorophyll_a_averages(start_date, end_date, lake)
print(f'Monthly chlorophyll-a averages saved to {final_output_file}')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Monthly chlorophyll-a averages saved to monthly_Chlorophyll_a_averages.csv

# %%
# Define the function to compute monthly SSC averages
def compute_monthly_SSC_averages(start_date, end_date, lake, scale=500):
    # Define the date range
    start = ee.Date(start_date)
    end = ee.Date(end_date)
    
    # Generate a list of months
    months = pd.date_range(start_date, end_date, freq='MS').strftime("%Y-%m").tolist()

    all_stats = []

    for month in months:
        month_start = ee.Date(f'{month}-01')
        month_end = month_start.advance(1, 'month')
        
        # Filter the dataset for the month and select the NDCI band
        monthly_SSC = processed_dataset.filterDate(month_start, month_end).select('SSC').mean()
        
        # Ensure the image has the band
        if monthly_SSC.bandNames().size().getInfo() == 0:
            print(f"No data for {month}")
            continue
        
        # Compute the zonal statistics for the region
        stats = geemap.zonal_stats(
            monthly_SSC, 
            lake, 
            None,  # No need to save intermediate files
            stat_type='MEAN', 
            scale=scale, 
            return_fc=True
        )
        
        # Convert the results to a DataFrame and add the month column
        df = geemap.ee_to_df(stats)
        df['month'] = month
        all_stats.append(df)
    
    # Concatenate all monthly DataFrames into a single DataFrame
    final_df = pd.concat(all_stats, ignore_index=True)
    
    # Save the final DataFrame to a CSV file
    final_output_file = 'monthly_SSC_a_averages.csv'
    final_df.to_csv(final_output_file, index=False)
    
    return final_output_file
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Compute the monthly SSC averages
final_output_file = compute_monthly_SSC_averages(start_date, end_date, lake)
print(f'Monthly SSC averages saved to {final_output_file}')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Monthly SSC averages saved to monthly_SSC_a_averages.csv

# %%
# Define the function to compute monthly turbidity averages
def compute_monthly_turbidity_averages(start_date, end_date, lake, scale=500):
    # Define the date range
    start = ee.Date(start_date)
    end = ee.Date(end_date)
    
    # Generate a list of months
    months = pd.date_range(start_date, end_date, freq='MS').strftime("%Y-%m").tolist()

    all_stats = []

    for month in months:
        month_start = ee.Date(f'{month}-01')
        month_end = month_start.advance(1, 'month')
        
        # Filter the dataset for the month and select the NDCI band
        monthly_turbidity = processed_dataset.filterDate(month_start, month_end).select('Turbidity').mean()
        
        # Ensure the image has the band
        if monthly_turbidity.bandNames().size().getInfo() == 0:
            print(f"No data for {month}")
            continue
        
        # Compute the zonal statistics for the region
        stats = geemap.zonal_stats(
            monthly_turbidity, 
            lake, 
            None,  # No need to save intermediate files
            stat_type='MEAN', 
            scale=scale, 
            return_fc=True
        )
        
        # Convert the results to a DataFrame and add the month column
        df = geemap.ee_to_df(stats)
        df['month'] = month
        all_stats.append(df)
    
    # Concatenate all monthly DataFrames into a single DataFrame
    final_df = pd.concat(all_stats, ignore_index=True)
    
    # Save the final DataFrame to a CSV file
    final_output_file = 'monthly_turbidity_averages.csv'
    final_df.to_csv(final_output_file, index=False)
    
    return final_output_file

# %%
# Compute the monthly Turbidity averages
final_output_file = compute_monthly_turbidity_averages(start_date, end_date, lake)
print(f'Monthly turbidity averages saved to {final_output_file}')
# Out:
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Computing statistics ...
# Monthly turbidity averages saved to monthly_turbidity_averages.csv
